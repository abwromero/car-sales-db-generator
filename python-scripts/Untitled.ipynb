# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup("https://www.carguide.ph/p/philippine-car-price-guide-2016_18.html")
# Out:
# /tmp/ipykernel_2135/1654733550.py:1: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   soup = BeautifulSoup("https://www.carguide.ph/p/philippine-car-price-guide-2016_18.html")

# %%
print(soup.prettify())
# Out:
# https://www.carguide.ph/p/philippine-car-price-guide-2016_18.html

# %%
import requests

# %%
r = requests.get("https://www.carguide.ph/p/philippine-car-price-guide-2016_18.html")

# %%
soup = BeautifulSoup(r.text)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="v2" dir="ltr" xmlns="http://www.w3.org/1999/xhtml" xmlns:b="http://www.google.com/2005/gml/b" xmlns:data="http://www.google.com/2005/gml/data" xmlns:expr="http://www.google.com/2005/gml/expr" xmlns:og="https://ogp.me/ns#">
#  <head>
#   <link href="https://www.blogger.com/static/v1/widgets/3566091532-css_bundle_v2.css" rel="stylesheet" type="text/css"/>
#   <meta content="IE=EmulateIE7" https-equiv="X-UA-Compatible"/>
#   <meta content="width=1100" name="viewport"/>
#   <title>
#    CarGuide.PH's Philippine New Car Price Guide | CarGuide.PH | Philippine Car News, Car Reviews, Car Prices
#   </title>
#   <!-- Begin Open Graph metadata -->
#   <meta content="en_US" property="og:locale"/>
#   <meta content="https://www.carguide.ph/p/philippine-car-price-guide-2016_18.html" property="og:url"/>
#   <meta content="CarGuide.PH | Philippine Car News, Car Reviews, Car Prices" property="og:site_name"/>
# ...

# %%
h4 = soup.find_all('h4')

# %%
print(h4)
# Out:
# [<h4>
# 	BMW</h4>, <h4>
# 	BYD</h4>, <h4>
# 	Changan</h4>, <h4>
# 	Chery</h4>, <h4>
# 	Chevrolet</h4>, <h4>
# 	Dodge</h4>, <h4>
# 	Dongfeng</h4>, <h4>
# 	Ford</h4>, <h4>
# 	Foton</h4>, <h4>
# 	GAC</h4>, <h4>
# 	Geely</h4>, <h4>
# 	Great Wall</h4>, <h4>
# 	Haima</h4>, <h4>
# 	Honda</h4>, <h4>
# 	Hongqi</h4>, <h4>
# 	Hyundai</h4>, <h4>
# 	Isuzu</h4>, <h4>
# 	JAC</h4>, <h4>
# 	Jaguar</h4>, <h4>
# 	Jeep</h4>, <h4>
# 	Jetour</h4>, <h4>
# 	JMC</h4>, <h4>
# 	Kaicene</h4>, <h4>
# 	Kia</h4>, <h4>
# 	Lexus</h4>, <h4>
# 	Land Rover</h4>, <h4>
# 	Maxus</h4>, <h4>
# 	Mazda</h4>, <h4>
# 	Mercedes-Benz</h4>, <h4>
# 	MG</h4>, <h4>
# 	Mini</h4>, <h4>
# 	Mitsubishi</h4>, <h4>
# 	Nissan</h4>, <h4>
# 	Peugeot</h4>, <h4>
# 	RAM</h4>, <h4>
# 	SsangYong</h4>, <h4>
# 	Subaru</h4>, <h4>
# 	Suzuki</h4>, <h4>
# 	Tata</h4>, <h4>
# 	Toyota</h4>, <h4>
# 	Volkswagen</h4>, <h4>
# 	Volvo</h4>, <h4>
# 	Weltmeister</h4>]

# %%
h4_list = []
for tag in h4:

# %%
soup.find_all('td')
# Out:
# [<td class="gsc-input">
#  <input autocomplete="off" class="gsc-input" name="q" size="10" title="search" type="text" value=""/>
#  </td>,
#  <td class="gsc-search-button">
#  <input class="gsc-search-button" title="search" type="submit" value="Search"/>
#  </td>,
#  <td>Model</td>,
#  <td>Price</td>,
#  <td><a href="https://www.carguide.ph/search/label/BMW%202%20Series">218i
#  		Coupe M Sport</a></td>,
#  <td>P 3,590,000 (AT)</td>,
#  <td><a href="https://www.carguide.ph/search/label/BMW%202%20Series">220i
#  		Coupe M Sport</a></td>,
#  <td>P 3,690,000 (AT)</td>,
#  <td><a href="https://www.carguide.ph/search/label/BMW%202%20Series">M240i
#  		Coupe M Sport</a></td>,
#  <td>P 4,890,000 (AT)</td>,
#  <td><a href="https://www.carguide.ph/search/label/BMW%203%20Series">318i
#  		Sport</a></td>,
#  <td>P 3,790,000 (AT)</td>,
#  <td><a href="https://www.carguide.ph/search/label/BMW%203%20Series">318i
#  		Touring</a></td>,
#  <td>P 3,890,000 (AT)</td>,
# ...

# %%
def has_class_and_id(tag):
    return tag.has_attr('class') and tag.has_attr('id')

# %%
soup.find_all(has_class_and_id)
# Out:
# [<div class="navbar section" id="navbar"><div class="widget Navbar" data-version="1" id="Navbar1"><script type="text/javascript">
#      function setAttributeOnload(object, attribute, val) {
#        if(window.addEventListener) {
#          window.addEventListener('load',
#            function(){ object[attribute] = val; }, false);
#        } else {
#          window.attachEvent('onload', function(){ object[attribute] = val; });
#        }
#      }
#    </script>
#  <div id="navbar-iframe-container"></div>
#  <script src="https://apis.google.com/js/platform.js" type="text/javascript"></script>
#  <script type="text/javascript">
#        gapi.load("gapi.iframes:gapi.iframes.style.bubble", function() {
#          if (gapi.iframes && gapi.iframes.getContext) {
#            gapi.iframes.getContext().openChild({
# ...
